# %%
import pandas as pd
import numpy as np
import glob

# %%
train =  pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
sample_sub = pd.read_csv('sample_submission.csv')

# %%
train.head()
# Out:
#    Unnamed: 0  checking_balance  months_loan_duration credit_history
# 0           0             -43.0                     6       critical  \
# 1           1              75.0                    48         repaid
# 2           3             -32.0                    42         repaid
# 3           5               NaN                    36         repaid
# 4           7             169.0                    36         repaid
#
#       purpose  amount  savings_balance employment_length  installment_rate
# 0    radio/tv    1169              NaN          13 years                 4  \
# 1    radio/tv    5951             89.0           2 years                 2
# 2   furniture    7882              9.0           5 years                 2
# 3   education    9055              NaN           2 years                 2
# 4  car (used)    6948             57.0           2 years                 2
#
#   personal_status  ... installment_plan   housing existing_credits  default
# 0          single  ...             none       own                2        0  \
# 1             NaN  ...             none       own                1        1
# 2          single  ...             none  for free                1        0
# 3          single  ...             none  for free                1        0
# 4          single  ...             none      rent                1        0
#
#   dependents     telephone  foreign_worker                      job  gender
# 0          1  2.349340e+09             yes         skilled employee    male  \
# 1          1           NaN             yes         skilled employee  female
# 2          2           NaN             yes         skilled employee    male
# 3          2  2.345788e+09             yes       unskilled resident    male
# 4          1  2.349962e+09             yes  mangement self-employed    male
#
#    Id
# 0   0
# 1   1
# 2   3
# 3   5
# 4   7
#
# [5 rows x 24 columns]

# %%
modes = train.mode().iloc[0]

# %%
train.columns
# Out:
# Index(['Unnamed: 0', 'checking_balance', 'months_loan_duration',
#        'credit_history', 'purpose', 'amount', 'savings_balance',
#        'employment_length', 'installment_rate', 'personal_status',
#        'other_debtors', 'residence_history', 'property', 'age',
#        'installment_plan', 'housing', 'existing_credits', 'default',
#        'dependents', 'telephone', 'foreign_worker', 'job', 'gender', 'Id'],
#       dtype='object')

# %%
def proc_data(df):
    df.fillna(modes, inplace=True)
    df['credit_history'] = pd.Categorical(df.credit_history)
    df['purpose'] = pd.Categorical(df.purpose)
    df['personal_status'] = pd.Categorical(df.personal_status)
    df['other_debtors'] = pd.Categorical(df.other_debtors)
    df['property'] = pd.Categorical(df.property)
    df['installment_plan'] = pd.Categorical(df.installment_plan)
    df['installment_rate'] = pd.Categorical(df.installment_rate)
    df['housing'] = pd.Categorical(df.housing)
    df['foreign_worker'] = pd.Categorical(df.foreign_worker)
    df['job'] = pd.Categorical(df.job)
    df['gender'] = pd.Categorical(df.gender)
    df['existing_credits'] = pd.Categorical(df.existing_credits)
    df['dependents'] = pd.Categorical(df.dependents)

# %%
proc_data(train)
proc_data(test)

# %%
train.head()
# Out:
#    Unnamed: 0  checking_balance  months_loan_duration credit_history
# 0           0             -43.0                     6       critical  \
# 1           1              75.0                    48         repaid
# 2           3             -32.0                    42         repaid
# 3           5              -8.0                    36         repaid
# 4           7             169.0                    36         repaid
#
#       purpose  amount  savings_balance employment_length installment_rate
# 0    radio/tv    1169             89.0          13 years                4  \
# 1    radio/tv    5951             89.0           2 years                2
# 2   furniture    7882              9.0           5 years                2
# 3   education    9055             89.0           2 years                2
# 4  car (used)    6948             57.0           2 years                2
#
#   personal_status  ... installment_plan   housing existing_credits  default
# 0          single  ...             none       own                2        0  \
# 1          single  ...             none       own                1        1
# 2          single  ...             none  for free                1        0
# 3          single  ...             none  for free                1        0
# 4          single  ...             none      rent                1        0
#
#   dependents     telephone foreign_worker                      job  gender  Id
# 0          1  2.349340e+09            yes         skilled employee    male   0
# 1          1  2.340000e+09            yes         skilled employee  female   1
# 2          2  2.340000e+09            yes         skilled employee    male   3
# 3          2  2.345788e+09            yes       unskilled resident    male   5
# 4          1  2.349962e+09            yes  mangement self-employed    male   7
#
# [5 rows x 24 columns]
# Bad pipe message: %s [b">\xf58he[D\x18G\xb2\x03\x15\xf7G-V\\u \x0f\xca\x8a\x9dm/\x0b\xad\xdc\xe0\\p\x99r\xfd\x97\x14\xd2N'\xddc\xb97\xdc\x18\x89\xd9z"]
# Bad pipe message: %s [b'4\x16Su)\x11w)\x8b\xd6\xcf\x04\x9f(M\xc7\xee\xc5 \xcd\xefv4\x8bwB\xd3\x8f\x1a26@\xc0\x08\x9fr\xf7?\xa3pr\x15\x99\xcb\x9a4i\x0c\xdd\xa5s\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 ']
# Bad pipe message: %s [b"\x9c\x88\x12\x8bs}\x1b\xc4G\x9d\x98Kbo\xc0\x08\x1bL\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00<\x005\x00/\x00\x9a\x00\x99\xc0\x07\xc0\x11\x00\x96\x00\x05\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1"]
# Bad pipe message: %s [b"\xd9u7\xe2\x07\t\x13Oq$*\xc06\xcfX\xa0t\xcd\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0\x12\x00\x16"]
# Bad pipe message: %s [b'S\xed\xf1\xc7\xdc\xf0$\xce\x04\x04\xb0\xeah\xafz\xd9f=\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c']
# Bad pipe message: %s [b't\x927\xce:\x88\xdc@-\x06\x98/4D\xdc\x97\xd6\x88\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04']
# Bad pipe message: %s [b'\xf6\x85']
# Bad pipe message: %s [b'=\x1c\xc9\x1e\xa9\x12\xf5\xf1\xcfH\xb4\x9e\x9e\xa4\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00', b'\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00']
# Bad pipe message: %s [b'^{X\xe2D2\xb8!\xad\x05\xf7\r\xca\xfeQ\xd5\xa3b\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002']
# Bad pipe message: %s [b'\x81~V\xe3Av\xcd\xb0\xd3\xc8\x89\x90\xdcE\x08\x8a\xd0\xdb\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00']
# Bad pipe message: %s [b'z"\r} \xaf\xaf\xe0\xa2v\x99\xfb\xd1\xb0c\xcd\xb2N\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05']
# Bad pipe message: %s [b'n6/W\x91\xafs9\x7f\x8cE\xcdG\n\xba.\xc51\x00\x00\x86\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008']
# Bad pipe message: %s [b"\xb8-v0\x91@y\xd1:\xaf\x91\xba\xc1n\xe8c:\xe7\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2"]
